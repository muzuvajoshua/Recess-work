# %%
#CHECKING panda version
import pandas as pd
print(pd.__version__)
# Out:
# 1.4.2

# %%
#creating a data set
import pandas as pd

mydataset = {
    
    'cars' : ["tesla", "audi","jeep"],
    'year of make': [2021,2017,2010]
}

myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  year of make
# 0  tesla          2021
# 1   audi          2017
# 2   jeep          2010

# %%
#reading a csv file
import pandas as pd
df = pd.read_csv('music.csv')
print(df.to_string())


df = pd.read_csv('transactions.csv')
print(df.to_string())
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical
#    transaction_id  product_id price
# 0            1001           1  $5.95
# 1            1002           2  $6.95
# 2            1003           3  $7.95

# %%
#panda series - is like a column in a table
football_clubs = ['Sevilla','Mancity','Manu','Real Madrid','Barcelona']

champs = pd.Series(football_clubs)
print(champs)
# Out:
# 0        Sevilla
# 1        Mancity
# 2           Manu
# 3    Real Madrid
# 4      Barcelona
# dtype: object

# %%
# Panda DataFrames
mylist = {
    'name':['Jack','jade','Jane','Jan'],
    'age':[10,90,78,56]
}
var = pd.DataFrame(mylist)
print(var)
# Out:
#    name  age
# 0  Jack   10
# 1  jade   90
# 2  Jane   78
# 3   Jan   56

# %%
df = pd.read_csv('Admission_Predict.csv')
print(df.to_string())
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  Chance of Admit
# 0             1        337          118                  4  4.5   4.5  9.65         1              0.92
# 1             2        324          107                  4  4.0   4.5  8.87         1              0.76
# 2             3        316          104                  3  3.0   3.5  8.00         1              0.72
# 3             4        322          110                  3  3.5   2.5  8.67         1              0.80
# 4             5        314          103                  2  2.0   3.0  8.21         0              0.65
# 5             6        330          115                  5  4.5   3.0  9.34         1              0.90
# 6             7        321          109                  3  3.0   4.0  8.20         1              0.75
# 7             8        308          101                  2  3.0   4.0  7.90         0              0.68
# ...

# %%
#manipulating data
print("Admissions_Predicts")
print("these are the first 5")
df.head()
# Out:
# Admissions_Predicts
# these are the first 5
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
print("Admissions_Predicts")
print("these are the last 5")
df.tail()
# Out:
# Admissions_Predicts
# these are the last 5
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
#get main intiution
print('Admission_Predict.csv')
df.describe()
# Out:
# Admission_Predict.csv
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# ...

# %%
#to get more information about the data set (method called).info()
print("Admission_Predict")
df.info()
#show columns
df.columns


#show data shape
df.shape
# Out:
# Admission_Predict
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB
# (400, 9)

# %%
#show null values use method for Null value
df.isnull().sum()#incase of null values use dropna() to drop null values
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
data = pd.read_csv('nulldataset.csv')
print(data.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
data.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
data_new = data.dropna()
print(data_new.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
data_new.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
data_new.shape
# Out:
# (164, 4)

# %%
#Data visualisation with Pandas
import pandas as pd
import matplotlib.pyplot as plt

data_predict = pd.read_csv('Admission_Predict.csv')
#print(data_predict.to_string())
data_predict.plot()
plt.show()

# %%
data_predict.plot(kind = 'scatter', x='CGPA',y='SOP')
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='SOP'>

# %%
data_predict.plot(kind = 'scatter', x='Research',y='TOEFL Score')
# Out:
# <AxesSubplot:xlabel='Research', ylabel='TOEFL Score'>

# %%
data_predict['CGPA'].plot(kind ='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_predict.plot(kind ='scatter',x='CGPA',y='TOEFL Score', figsize=(15,15))
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='TOEFL Score'>

# %%
data_predict['GRE Score'].plot.hist(color='red')
# Out:
# <AxesSubplot:ylabel='Frequency'>
